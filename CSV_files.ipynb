# %%
import pandas as pd

# Load dataset
df = pd.read_csv("Consumption.csv")

# Conveimport pandas as pd

# Load dataset
df = pd.read_csv("Consumption.csv")

# Display first 5 rows
print("First 5 rows of dataset:")
print(df.head())

# Check dataset info
print("\nDataset Info:")
print(df.info())

# Check missing values
print("\nMissing Values:")
print(df.isnull().sum())

# Check duplicate rows
duplicates = df.duplicated().sum()
print("\nNumber of duplicate rows:", duplicates)

# Remove duplicates
df = df.drop_duplicates()

# Convert Dates column to datetime format
df['Dates'] = pd.to_datetime(df['Dates'], dayfirst=True)

# Check unique regions
print("\nRegions in dataset:")
print(df['Regions'].unique())

# Basic statistics of Usage
print("\nUsage statistics:")
print(df['Usage'].describe())

# Save cleaned dataset
df.to_csv("Consumption_cleaned.csv", index=False)

print("\nCleaned dataset saved as Consumption_cleaned.csv")
# Out:
# First 5 rows of dataset:
#       States Regions   latitude  longitude       Dates  Usage
# 0     Punjab      NR  31.519974  75.980003  02/01/2019  119.9
# 1    Haryana      NR  28.450006  77.019991  02/01/2019  130.3
# 2  Rajasthan      NR  26.449999  74.639981  02/01/2019  234.1
# 3      Delhi      NR  28.669993  77.230004  02/01/2019   85.8
# 4         UP      NR  27.599981  78.050006  02/01/2019  313.9
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16599 entries, 0 to 16598
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   States     16599 non-null  object
#  1   Regions    16599 non-null  object
#  2   latitude   16599 non-null  float64
#  3   longitude  16599 non-null  float64
#  4   Dates      16599 non-null  object
#  5   Usage      16599 non-null  float64
# dtypes: float64(3), object(3)
# memory usage: 778.2+ KB
# None
#
# Missing Values:
# States       0
# Regions      0
# ...
